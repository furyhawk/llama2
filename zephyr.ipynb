# %%
from transformers import AutoTokenizer
import transformers
import torch

# %%
model = "HuggingFaceH4/zephyr-7b-alpha"

tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="cpu",
)

sequences = pipeline(
    'I liked "Breaking Bad" and "Band of Brothers". Do you have any recommendations of other shows I might like?\n',
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=200,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/furyhawk/projects/llama2/zephyr.ipynb Cell 2 line 1
#       <a href='vscode-notebook-cell:/Users/furyhawk/projects/llama2/zephyr.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> tokenizer = AutoTokenizer.from_pretrained(model)
#       <a href='vscode-notebook-cell:/Users/furyhawk/projects/llama2/zephyr.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> pipeline = transformers.pipeline(
#       <a href='vscode-notebook-cell:/Users/furyhawk/projects/llama2/zephyr.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a>     "text-generation",
# ...

# %%
llm_chain = LLMChain(prompt=prompt, llm=llm)
question = "What NFL team won the Super Bowl in the year Justin Bieber was born?"
llm_chain.run(question)

# %%
prompt_template = """
I want you to act as a histopathology assistant. \
I will provide a report, and you will extract the following histopathological \
variables from the report: {variable_list} \

Return as a JSON format with each histopathological variable as a key. \
Be concise in the JSON format values. \
If there are multiple values for a given key, return as a list of strings. \
If you do not know, or if the information is not available, return null. \
Do not return anything else other than the JSON format.

Here is the report:
{report}
JSON format:
"""

# %%
llm_chain = LLMChain.from_string(llm=llm, template=prompt_template)

# %%
json_string = llm_chain.predict(variable_list=variable_list, report=df["Full report"][0])
print(json_string)
